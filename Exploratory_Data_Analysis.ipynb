# %% [markdown]
# #NOTE
#
# > **Please upload all the required files, before running the notebook. For this notebook the required files are - ecommerce_sales_analysis.csv**

# %% [markdown]
# # 5310: Methods in Empirical Analysis Task # 1
# # Exploratory data analysis in Python.

# %% [markdown]
# **What is Exploratory Data Analysis ?**
#
# Exploratory Data Analysis or (EDA) is understanding the data sets by summarizing their main characteristics often plotting them visually. This step is very important especially when we arrive at modeling the data in order to apply Machine learning. Plotting in EDA consists of Histograms, Box plot, Scatter plot and many more. It often takes much time to explore the data. Through the process of EDA, we can ask to define the problem statement or definition on our data set which is very important.

# %% [markdown]
# **How to perform Exploratory Data Analysis ?**
#
# This is one such question that everyone is keen on knowing the answer. Well, the answer is it depends on the data set that you are working. There is no one method or common methods in order to perform EDA, whereas in this tutorial you can understand some common methods and plots that would be used in the EDA process.

# %% [markdown]
# **What data are we exploring today ?**
#
#
#
# For this activity, i have taken an **ecommerce sales dataset** from Kaggle. The data-set can be downloaded from [here](https://www.kaggle.com/datasets/fahmidachowdhury/e-commerce-sales-analysis). To give a piece of brief information about the data set this data contains about 1000 rows and more than 10 columns which contains features of the product such as product_id, product_name, category etc. So in this tutorial, we will explore the data and make it ready for modeling.

# %% [markdown]
# ## Importing the required libraries for EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)

# %% [markdown]
# ## Loading the data into the data frame.

# %%
df = pd.read_csv("/content/ecommerce_sales_analysis.csv")
#To Display top 5 rows
df.head(5)
# Out:
#    product_id product_name        category   price  review_score  \
# 0           1    Product_1        Clothing  190.40           1.7
# 1           2    Product_2  Home & Kitchen  475.60           3.2
# 2           3    Product_3            Toys  367.34           4.5
# 3           4    Product_4            Toys  301.34           3.9
# 4           5    Product_5           Books   82.23           4.2
#
#    review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 0           220            479            449             92            784
# 1           903             21            989            861            863
# 2           163            348            558            567            143
# 3           951            725            678             59             15
# 4           220            682            451            649            301
#
#    sales_month_5  sales_month_6  sales_month_7  sales_month_8  sales_month_9  \
# ...

# %%
#To Display last 5 rows
df.tail(5)
# Out:
#      product_id  product_name        category   price  review_score  \
# 995         996   Product_996  Home & Kitchen   50.33           3.6
# 996         997   Product_997  Home & Kitchen  459.07           4.8
# 997         998   Product_998          Sports   72.73           1.3
# 998         999   Product_999          Sports  475.37           1.2
# 999        1000  Product_1000            Toys  225.77           2.1
#
#      review_count  sales_month_1  sales_month_2  sales_month_3  sales_month_4  \
# 995           494            488            359            137            787
# 996           701             18            906            129             78
# 997           287            725            109            193            657
# 998           720            196            191            315            622
# 999           114            890            903            983            769
#
#      sales_month_5  sales_month_6  sales_month_7  sales_month_8  \
# ...

# %% [markdown]
# ## Drop irrelevant columns

# %% [markdown]
# Here features like product_id, product_name and category are not required for our analysis, so we drop them.

# %%
df.drop(['product_id','product_name','category'], axis=1, inplace=True)
df.head(5)
# Out:
#     price  review_score  review_count  sales_month_1  sales_month_2  \
# 0  190.40           1.7           220            479            449
# 1  475.60           3.2           903             21            989
# 2  367.34           4.5           163            348            558
# 3  301.34           3.9           951            725            678
# 4   82.23           4.2           220            682            451
#
#    sales_month_3  sales_month_4  sales_month_5  sales_month_6  sales_month_7  \
# 0             92            784            604            904            446
# 1            861            863            524            128            610
# 2            567            143            771            409            290
# 3             59             15            937            421            670
# 4            649            301            620            293            411
#
#    sales_month_8  sales_month_9  sales_month_10  sales_month_11  \
# ...

# %% [markdown]
# # Rename Columns

# %% [markdown]
# I'm gonna rename the features like "sales_month_1", etc to month names "JAN" etc for better understanding and easy typing

# %%
df = df.rename(columns={"sales_month_1": "JAN", "sales_month_2": "FEB"})
df.head(5)
# Out:
#     price  review_score  review_count  JAN  FEB  sales_month_3  sales_month_4  \
# 0  190.40           1.7           220  479  449             92            784
# 1  475.60           3.2           903   21  989            861            863
# 2  367.34           4.5           163  348  558            567            143
# 3  301.34           3.9           951  725  678             59             15
# 4   82.23           4.2           220  682  451            649            301
#
#    sales_month_5  sales_month_6  sales_month_7  sales_month_8  sales_month_9  \
# 0            604            904            446            603            807
# 1            524            128            610            436            176
# 2            771            409            290            828            340
# 3            937            421            670            933             56
# 4            620            293            411            258            854
#
# ...

# %%
df = df.rename(columns={"sales_month_3": "MAR", "sales_month_4": "APR", "sales_month_5":"MAY",
                        "sales_month_6":"JUN","sales_month_7" : "JUL", "sales_month_8" : "AUG",
                        "sales_month_9" : "SEP", "sales_month_10" : "OCT","sales_month_11" : "NOV", "sales_month_12":"DEC"})
df.head(5)
# Out:
#     price  review_score  review_count  JAN  FEB  MAR  APR  MAY  JUN  JUL  AUG  \
# 0  190.40           1.7           220  479  449   92  784  604  904  446  603
# 1  475.60           3.2           903   21  989  861  863  524  128  610  436
# 2  367.34           4.5           163  348  558  567  143  771  409  290  828
# 3  301.34           3.9           951  725  678   59   15  937  421  670  933
# 4   82.23           4.2           220  682  451  649  301  620  293  411  258
#
#    SEP  OCT  NOV  DEC
# 0  807  252  695  306
# 1  176  294  772  353
# 2  340  667  267  392
# 3   56  157  168  203
# 4  854  548  770  257

# %% [markdown]
# ## Shape of Dataframe

# %%
#finding no. of rows & columns of the dataframe
df.shape
# Out:
# (1000, 15)

# %% [markdown]
# ## Display Columns & their datatypes

# %%
#list of columns
df.columns
# Out:
# Index(['price', 'review_score', 'review_count', 'JAN', 'FEB', 'MAR', 'APR',
#        'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'],
#       dtype='object')

# %%
#their datatypes
df.dtypes
# Out:
# price           float64
# review_score    float64
# review_count      int64
# JAN               int64
# FEB               int64
# MAR               int64
# APR               int64
# MAY               int64
# JUN               int64
# JUL               int64
# AUG               int64
# SEP               int64
# OCT               int64
# NOV               int64
# DEC               int64
# dtype: object

# %% [markdown]
# # Check & Remove Duplicates

# %% [markdown]
# Now i'm gonna check for any duplicates in the dataset using the duplicated() function in Python, it returns the no. of duplicated rows present in the dataset

# %%
duplicate_rows_df = df[df.duplicated()]
print("number of duplicate rows: ", duplicate_rows_df.shape)
# Out:
# number of duplicate rows:  (0, 15)

# %%
df.count()
# Out:
# price           1000
# review_score    1000
# review_count    1000
# JAN             1000
# FEB             1000
# MAR             1000
# APR             1000
# MAY             1000
# JUN             1000
# JUL             1000
# AUG             1000
# SEP             1000
# OCT             1000
# NOV             1000
# DEC             1000
# dtype: int64

# %% [markdown]
# Luckily, there are no duplicates in the dataset i have choosen, now i will check for any missing values in the data

# %% [markdown]
# # Check for Missing Values

# %% [markdown]
# the isnull() returns False if there is a value else True if the value is *null*. sum() function will check the number of *Trues* in the result. Basically returning the count of rows with null values.

# %%
print(df.isnull().sum())
# Out:
# price           0
# review_score    0
# review_count    0
# JAN             0
# FEB             0
# MAR             0
# APR             0
# MAY             0
# JUN             0
# JUL             0
# AUG             0
# SEP             0
# OCT             0
# NOV             0
# DEC             0
# dtype: int64

# %% [markdown]
# Now i'll check for outliers, this can be done using two ways:
#
# *   Using Box Plot
# *   Using Quartiles

# %% [markdown]
# # Check for outliers

# %%
df.boxplot(column = ['JAN', 'FEB','MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
# Out:
# <Axes: >

# %%
df.boxplot(column=['price','review_count'])
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['review_score'])
# Out:
# <Axes: xlabel='review_score'>

# %% [markdown]
# Using box plots, we can see there are no outliers in the dataset, as there were no points that went beyond the plot.
#
# Now we will calculate Interquartile Range (IQR). This is a measure of statistical dispersion and is mainly used to identify outliers and understanding the spread of the data.

# %%
df.shape
# Out:
# (1000, 15)

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# price           251.625
# review_score      2.000
# review_count    488.250
# JAN             495.250
# FEB             493.750
# MAR             533.500
# APR             488.000
# MAY             506.000
# JUN             504.500
# JUL             503.250
# AUG             521.750
# SEP             488.000
# OCT             503.250
# NOV             509.750
# DEC             471.000
# dtype: float64

# %%
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df.shape
# Out:
# (1000, 15)

# %% [markdown]
# Here all the 1000 rows of data fall under the given quartile range and our data is completely preprocessed and ready for training.
# Now, let's understand the relation between different features in the dataset.

# %% [markdown]
# ## 9. Plot different features against one another (scatter), against frequency (histogram)

# %% [markdown]
# ### Histogram
#
# Histogram refers to the frequency of occurrence of variables in an interval. In this case, there are mainly 10 different types of car manufacturing companies, but it is often important to know who has the most number of cars. To do this histogram is one of the trivial solutions which lets us know the total number of car manufactured by a different company.

# %%
#histogram of 'review_count'
plt.hist(df['review_count'])
plt.title('review_count Histogram')
plt.xlabel('review_count')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# From the above histogram, we can understand the no of products with different review count. There are about y products with about x amount of reviews, where x is a value taken from x-axis and y is taken from y-axis. For instance, there are about 93 product with review count in the range of 200-400.

# %%
plt.scatter(df['review_score'], df['price'])
plt.show()

# %% [markdown]
# The above scatter plot shows relation between 'price' and 'review score' of a product.

# %%
plt.bar(df['review_count'], df['price'], color='skyblue', edgecolor='green', width=0.5)
plt.title('review_count vs price')
plt.xlabel('review_count')
plt.ylabel('price')
plt.show()

# %% [markdown]
# The above bar plot shows relation between 'price' and 'review count' of a product. We can understand from the above graph that most of the price is in the range of 300~500 and review_count is evenly distributed

# %% [markdown]
# ### Heat Maps
#
# Heat Maps is a type of plot which is necessary when we need to find the dependent variables. One of the best way to find the relationship between the features can be done using heat maps. In the below heat map we know that the price feature depends mainly on the review_count, APR,(positive correlation) & JUN (Negative correlation) Sales.

# %%
plt.figure(figsize=(11,9))
c= df.corr()
sns.heatmap(c,cmap="viridis",annot=True, fmt=".2f")
c
# Out:
#                  price  review_score  review_count       JAN       FEB  \
# price         1.000000      0.028960      0.042189 -0.033860 -0.002978
# review_score  0.028960      1.000000      0.027351  0.023949 -0.076709
# review_count  0.042189      0.027351      1.000000 -0.019286 -0.036431
# JAN          -0.033860      0.023949     -0.019286  1.000000  0.051889
# FEB          -0.002978     -0.076709     -0.036431  0.051889  1.000000
# MAR          -0.023203     -0.012420     -0.029381  0.006204 -0.012759
# APR           0.044579     -0.016875     -0.021719  0.048705 -0.100955
# MAY           0.030024     -0.038930     -0.013798  0.016276  0.056114
# JUN          -0.051430      0.017519     -0.006579  0.036269  0.035142
# JUL          -0.027996     -0.005810      0.029836  0.034670 -0.040520
# AUG          -0.045065      0.020471     -0.000519  0.009454 -0.022778
# SEP          -0.008224      0.019554     -0.020332  0.042872  0.004930
# ...

# %% [markdown]
# ### Key Understanding points from this activity
#
#
# *   Loading the data into a proper format to perform data analysis
# *   Basic pre processing of the data along with removing missing values and duplicates, finding outliers and removing them
# *   Identifying outliers using box plot and removing them using Interquartile range technique
# *   Visualising the data like plotting bar, scatter, histogram, joint plots and Heat maps to understanding the relation among various features within the dataset.
